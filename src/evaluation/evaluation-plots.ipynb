# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Compared against LongplayingPolicy

# %%
against_lpp_winning_ratio_dict = {'Agent': ["Less Observation", "More Observation", "Trained against Agents"]
    , 'Winning Ratio': [0.66, 0.894, 0.908]}

sns.barplot(data=pd.DataFrame(against_lpp_winning_ratio_dict), x="Agent", y="Winning Ratio")
# Out:
# <AxesSubplot: xlabel='Agent', ylabel='Winning Ratio'>

# %%
against_average_points_dict = {'Agent': ["Less Observation", "More Observation", "Trained against Agents"]
    , 'Average Points': [23.50, 43.03, 47.49]}

sns.barplot(data=pd.DataFrame(against_average_points_dict), x="Agent", y="Average Points")
# Out:
# <AxesSubplot: xlabel='Agent', ylabel='Average Points'>

# %% [markdown]
# # Compared against Random Agent

# %%
against_rand_winning_ratio_dict = {'Agent': ["Less Observation", "More Observation", "Trained against Agents"]
    , 'Winning Ratio': [95.6, 99.8, 100]}

sns.barplot(data=pd.DataFrame(against_rand_winning_ratio_dict), x="Agent", y="Winning Ratio")
# Out:
# <AxesSubplot: xlabel='Agent', ylabel='Winning Ratio'>

# %%
against_rand_average_points_dict = {'Agent': ["Less Observation", "More Observation", "Trained against Agents"]
    , 'Average Points': [24.01, 43.23, 50.25]}

sns.barplot(data=pd.DataFrame(against_rand_average_points_dict), x="Agent", y="Average Points")
# Out:
# <AxesSubplot: xlabel='Agent', ylabel='Average Points'>

# %% [markdown]
# # Against Human Player

# %%
against_rand_average_points_dict = {'Agent': ["Less Observation", "More Observation", "Trained against Agents"]
    , 'Average Points': [24.01, 43.23, 50.25]}

sns(data=pd.DataFrame(against_rand_average_points_dict), x="Agent", y="Average Points")
